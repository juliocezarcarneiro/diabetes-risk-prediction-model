# %%
# Step 1: Import libraries
import pandas as pd
import matplotlib.pyplot as plt

# Step 2: Create a dataframe with model names and their accuracies
model_results = pd.DataFrame({
    "Model": ["Logistic Regression", "Random Forest", "XGBoost", "Neural Network"],
    "Accuracy": [0.8048, 0.9094, 0.8149, 0.8100]
})

# Show the table
model_results
# Out:
#                  Model  Accuracy
# 0  Logistic Regression    0.8048
# 1        Random Forest    0.9094
# 2              XGBoost    0.8149
# 3       Neural Network    0.8100

# %%
import matplotlib.pyplot as plt

# Set the figure size
plt.figure(figsize=(8, 5))

# Create a bar chart
plt.bar(comparison_df['Model'], comparison_df['Accuracy'])

# Add chart labels and title
plt.title('Model Accuracy Comparison')
plt.ylabel('Accuracy')
plt.ylim(0.75, 0.95)  # Set y-axis range for better visibility

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Set figure size
plt.figure(figsize=(8, 5))

# Create a bar chart
plt.bar(comparison_df['Model'], comparison_df['Accuracy'], color='skyblue')

# Add chart labels and title
plt.title('Model Accuracy Comparison')
plt.xlabel('Model')
plt.ylabel('Accuracy')
plt.ylim(0.7, 1)  # Set y-axis limits to zoom into the differences
plt.grid(axis='y')

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Sort the DataFrame by accuracy for nicer visual
comparison_df_sorted = comparison_df.sort_values(by='Accuracy', ascending=True)

# Create a horizontal bar chart
plt.figure(figsize=(8, 5))
bars = plt.barh(comparison_df_sorted['Model'], comparison_df_sorted['Accuracy'], color='mediumseagreen')

# Add value labels to bars
for bar in bars:
    width = bar.get_width()
    plt.text(width + 0.005, bar.get_y() + bar.get_height()/2, f"{width:.4f}", va='center')

# Add labels and title
plt.title('Model Accuracy Comparison')
plt.xlabel('Accuracy')
plt.xlim(0.7, 1)
plt.grid(axis='x')

plt.tight_layout()
plt.show()

# %% [markdown]
# # 🔍 Model Accuracy Comparison Report

# %% [markdown]
# We evaluated four different machine learning models to predict diabetes risk using our merged and cleaned dataset. Below is the summary of each model’s accuracy score:
#
# Model	Accuracy Score
#
# Logistic Regression	0.8048
# Random Forest	0.9094 ✅ (Highest)
# XGBoost	0.8149
# Neural Network (DNN)	0.8100

# %% [markdown]
# 🏆 Top Performing Model: Random Forest
# The Random Forest Classifier delivered the highest accuracy of 90.94%, making it the most effective model for this binary classification task.
#
# 📌 Key Insights:
# All models achieved over 80% accuracy, showing the dataset is predictive.
#
# Random Forest showed excellent generalization and balance.
#
# Neural Network and XGBoost were slightly better than Logistic Regression but did not outperform Random Forest.
#
# Logistic Regression performed well and is still a strong baseline model.
